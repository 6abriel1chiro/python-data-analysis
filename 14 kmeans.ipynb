# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %matplotlib inline

# %%
vinos = pd.read_csv('dataset/vinos.csv', engine='python',index_col = 0)

# %%
vinos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 1 to 178
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Alcohol          178 non-null    float64
#  1   Malic            178 non-null    float64
#  2   Ash              178 non-null    float64
#  3   Alcalinity       178 non-null    float64
#  4   Magnesium        178 non-null    int64
#  5   Phenols          178 non-null    float64
#  6   Flavanoids       178 non-null    float64
#  7   Nonflavanoids    178 non-null    float64
#  8   Proanthocyanins  178 non-null    float64
#  9   Color            178 non-null    float64
#  10  Hue              178 non-null    float64
#  11  Dilution         178 non-null    float64
#  12  Proline          178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 19.5 KB

# %%
vinos.head()
# Out:
#       Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# Vino
# 1       14.23   1.71  2.43        15.6        127     2.80        3.06
# 2       13.20   1.78  2.14        11.2        100     2.65        2.76
# 3       13.16   2.36  2.67        18.6        101     2.80        3.24
# 4       14.37   1.95  2.50        16.8        113     3.85        3.49
# 5       13.24   2.59  2.87        21.0        118     2.80        2.69
#
#       Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# Vino
# 1              0.28             2.29   5.64  1.04      3.92     1065
# 2              0.26             1.28   4.38  1.05      3.40     1050
# 3              0.30             2.81   5.68  1.03      3.17     1185
# 4              0.24             2.18   7.80  0.86      3.45     1480
# 5              0.39             1.82   4.32  1.04      2.93      735

# %%
vinos_norm = (vinos - vinos.min()) / (vinos.max()-vinos.min())

# %%
vinos_norm
# Out:
#        Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# Vino
# 1     0.842105  0.191700  0.572193    0.257732   0.619565  0.627586
# 2     0.571053  0.205534  0.417112    0.030928   0.326087  0.575862
# 3     0.560526  0.320158  0.700535    0.412371   0.336957  0.627586
# 4     0.878947  0.239130  0.609626    0.319588   0.467391  0.989655
# 5     0.581579  0.365613  0.807487    0.536082   0.521739  0.627586
# ...        ...       ...       ...         ...        ...       ...
# 174   0.705263  0.970356  0.582888    0.510309   0.271739  0.241379
# 175   0.623684  0.626482  0.598930    0.639175   0.347826  0.282759
# 176   0.589474  0.699605  0.481283    0.484536   0.543478  0.210345
# 177   0.563158  0.365613  0.540107    0.484536   0.543478  0.231034
# 178   0.815789  0.664032  0.737968    0.716495   0.282609  0.368966
#
#       Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  \
# Vino
# ...

# %%
vinos_norm.describe()
# Out:
#           Alcohol       Malic         Ash  Alcalinity   Magnesium     Phenols  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     0.518584    0.315484    0.538244    0.458502    0.323278    0.453487
# std      0.213639    0.220780    0.146708    0.172142    0.155244    0.215811
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.350658    0.170455    0.454545    0.340206    0.195652    0.262931
# 50%      0.531579    0.222332    0.534759    0.458763    0.304348    0.474138
# 75%      0.696711    0.462945    0.640374    0.561856    0.402174    0.627586
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Flavanoids  Nonflavanoids  Proanthocyanins       Color         Hue  \
# count  178.000000     178.000000       178.000000  178.000000  178.000000
# mean     0.356386       0.437460         0.372523    0.322363    0.388170
# ...

# %%
wcss=[]

for i in range(1,11):
    kmeans = KMeans(n_clusters = i ,max_iter = 300)
    kmeans.fit(vinos_norm)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('codo de jambu')
plt.xlabel('numero de clusters')
plt.ylabel('wcss')
plt.show()

# %%
clustering = KMeans(n_clusters=3, max_iter=300)
clustering.fit(vinos_norm)
# Out:
# KMeans(n_clusters=3)

# %%
vinos['kmeans'] = clustering.labels_
vinos.head()
# Out:
#       Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# Vino
# 1       14.23   1.71  2.43        15.6        127     2.80        3.06
# 2       13.20   1.78  2.14        11.2        100     2.65        2.76
# 3       13.16   2.36  2.67        18.6        101     2.80        3.24
# 4       14.37   1.95  2.50        16.8        113     3.85        3.49
# 5       13.24   2.59  2.87        21.0        118     2.80        2.69
#
#       Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  kmeans
# Vino
# 1              0.28             2.29   5.64  1.04      3.92     1065       2
# 2              0.26             1.28   4.38  1.05      3.40     1050       2
# 3              0.30             2.81   5.68  1.03      3.17     1185       2
# 4              0.24             2.18   7.80  0.86      3.45     1480       2
# 5              0.39             1.82   4.32  1.04      2.93      735       2

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_vinos = pca.fit_transform(vinos_norm)
pca_vinos_df = pd.DataFrame(data=pca_vinos, columns=['Componente_1', 'Componente_2'])
pca_nombres_vinos = pd.concat([pca_vinos_df,vinos[['kmeans']].astype('Int64')],axis=1)
pca_nombres_vinos
pca_nombres_vinos2=pca_nombres_vinos.iloc[1:177,:]
pca_nombres_vinos2
# Out:
#      Componente_1  Componente_2  kmeans
# 1       -0.484977     -0.008823       2
# 2       -0.521172     -0.189187       2
# 3       -0.821644     -0.580906       2
# 4       -0.202546     -0.059467       2
# 5       -0.608190     -0.487519       2
# ..            ...           ...     ...
# 172      0.537656     -0.462405       0
# 173      0.739510     -0.471901       0
# 174      0.581781     -0.348366       0
# 175      0.626313     -0.546857       0
# 176      0.572991     -0.425516       0
#
# [176 rows x 3 columns]

# %%
x = pca_nombres_vinos2['Componente_1'].values
y = pca_nombres_vinos2['Componente_2'].values
plt.xlabel = ('Componente 1')
plt.ylabel = ('Componente 2')
plt.title ('Componentes Principales')
plt.plot(x,y,'o',markersize= 1)
plt.show()
